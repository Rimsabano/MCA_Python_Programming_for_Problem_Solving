# %%
from shapes import Circle                 # absolute import
from shapes.circle import rectangle_area_demo

c = Circle(5)
print("Circle Area:", c.area())

print("Rectangle Area (via relative import):", rectangle_area_demo())
# Out:
# Circle Area: 78.5
# Rectangle Area (via relative import): 20
