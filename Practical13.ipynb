# %%
import random
import string
uppercase = string.ascii_uppercase
lowercase = string.ascii_lowercase
digits = string.digits
symbols = "!@#$*"

# %%
first_char = random.choice(uppercase + digits)
remaining = random.choices(uppercase + lowercase + digits + symbols, k=11)
password = first_char + "".join(remaining)
print("Generated Password:", password)
# Out:
# Generated Password: BVDgRsK$7SAA
