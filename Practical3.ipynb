# %%
num = int(input("Enter a number: "))
print("Entered:", num)
# Out:
# Entered: 12345678

# %%
reversed_num = int(str(num)[::-1])
print("Reversing process completed.")
# Out:
# Reversing process completed.

# %%
print("Reversed number:", reversed_num)
# Out:
# Reversed number: 87654321
