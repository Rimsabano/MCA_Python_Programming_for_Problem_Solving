# %%
data = [10, 20, 30, 40, 50]

index = input("Enter index: ")

# %%
try:
    index = int(index)
    print("Element:", data[index])
except Exception as e:
    print("Error:", e)
# Out:
# Error: list index out of range
