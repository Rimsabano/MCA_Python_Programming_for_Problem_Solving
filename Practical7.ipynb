# %%
data = input('Enter items separated by commas: ')
items = [x.strip() for x in data.split(',')]
print("You entered:", items)
# Out:
# You entered: ['pen', 'pencil', 'scale', 'table', 'chair']

# %%
unique_sorted_items = sorted(set(items))
print("Processing completed.")
# Out:
# Processing completed.

# %%
print("Unique & Sorted Items:", unique_sorted_items)
# Out:
# Unique & Sorted Items: ['chair', 'pen', 'pencil', 'scale', 'table']
