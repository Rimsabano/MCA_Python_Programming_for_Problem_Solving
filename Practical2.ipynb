# %%
text = input("Enter a string: ")
print("Entered:", text)
# Out:
# Entered: university

# %%
vowels = "aeiouAEIOU"

count = 0

for char in text:
    if char in vowels:
        count += 1

print("Counting vowels completed.")
# Out:
# Counting vowels completed.

# %%
print("Number of vowels:", count)
# Out:
# Number of vowels: 4
