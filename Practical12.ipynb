# %%
import random
students = ["Amit", "Riya", "Sohan", "Neha", "Kunal"]

# %%
cr = random.choice(students)
random.shuffle(students)

print("Class Representative:", cr)
print("Shuffled student list:", students)
# Out:
# Class Representative: Kunal
# Shuffled student list: ['Sohan', 'Kunal', 'Riya', 'Amit', 'Neha']
